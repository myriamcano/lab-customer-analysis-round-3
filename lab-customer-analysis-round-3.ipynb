# %%
import pandas as pd

data=pd.read_csv('finaldata')
data
# Out:
#       Unnamed: 0 customer       state gender             education  \
# 0              1  QZ44356     Arizona      F              Bachelor
# 1              2  AI49188      Nevada      F              Bachelor
# 2              3  WW63253  California      M              Bachelor
# 3              4  GA49547  Washington      M  High School or Below
# 4              5  OC83172      Oregon      F              Bachelor
# ...          ...      ...         ...    ...                   ...
# 1063        1066  TM65736      Oregon      M                Master
# 1064        1067  VJ51327  California      F  High School or Below
# 1065        1068  GS98873     Arizona      F              Bachelor
# 1066        1069  CW49887  California      F                Master
# 1067        1070  MY31220  California      F               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      697953       0                    94
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

sns.countplot(x='gender', data=data) 
plt.xlabel('gender')
plt.ylabel('count')
plt.title('Gender Breakdown')
# Out:
# Text(0.5, 1.0, 'Gender Breakdown')

# %%
sns.barplot(x='state', y='income', data=data)
plt.xlabel('State')
plt.ylabel('Income')
plt.title('Income by State')
plt.show()

# %%
sns.barplot(x='policy_type', y='total_claim_amount', data=data)
plt.xlabel('Policy Type')
plt.ylabel('Total Claim Amount')

plt.show()

# %%
sns.countplot(x='vehicle_class', hue='education', data=data)
plt.xlabel('Vehicle Class')
plt.ylabel('Count')
plt.title('Education by Vehicle Class')
plt.legend(title='Education', loc='upper right', bbox_to_anchor=(1.2, 1.0))  # Display legend
plt.show()

# %%
# insights

#gender: there are more females than males in this dataset. 

#Income by state: washington is the state with the highest income this comes to be just above $50,000.

#the total claim amount by policy type is farly evenly distributed. special auto is comparatively lower than personal and corporate, the number of claims for the three policy types varies from a small range of 360 to 420.



#other beneficial plots count of number of claims by education type/income/gender
